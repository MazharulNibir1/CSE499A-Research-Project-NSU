# %%
# Import necessary libraries
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate, resize
from PIL import Image, ImageOps

# Neural imaging
import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt

# ML libraries
import keras
# import keras.backend as K
# from tensorflow.keras.layers as K

from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard

# Make numpy printouts easier to read
np.set_printoptions(precision=3, suppress=True)

# %%
# DEFINE seg-areas  
SEGMENT_CLASSES = {
    0 : 'NOT tumor',   
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE - RED
    2 : 'EDEMA',  # Green
    3 : 'ENHANCING' # original 4 -> converted into 3 later, Yellow
}

# there are 155 slices per volume
# to start at 5 and use 145 slices means we will skip the first 5 and last 5 
VOLUME_SLICES = 80 
VOLUME_START_AT = 60 # first slice of volume that we will include

IMG_SIZE=128

# %%
# Copy and rename the file to .zip, then extract it into a folder named processed_data
# !cp /kaggle/input/brats2023roi-full/brats2023roi/processed_data.whatever /kaggle/working/processed_data.zip && \
unzip /kaggle/working/processed_data.zip -d /kaggle/working/
# Out:
# /usr/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Archive:  /kaggle/working/processed_data.zip
#    creating: /kaggle/working/processed_data/
#    creating: /kaggle/working/processed_data/BraTS-GLI-00000-000/
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00000-000/BraTS-GLI-00000-000-seg.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t1c.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t1n.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t2f.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t2w.nii.gz
#    creating: /kaggle/working/processed_data/BraTS-GLI-00002-000/
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00002-000/BraTS-GLI-00002-000-seg.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00002-000/BraTS-GLI-00002-000-t1c.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00002-000/BraTS-GLI-00002-000-t1n.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00002-000/BraTS-GLI-00002-000-t2f.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00002-000/BraTS-GLI-00002-000-t2w.nii.gz
#    creating: /kaggle/working/processed_data/BraTS-GLI-00003-000/
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00003-000/BraTS-GLI-00003-000-seg.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00003-000/BraTS-GLI-00003-000-t1c.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00003-000/BraTS-GLI-00003-000-t1n.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00003-000/BraTS-GLI-00003-000-t2f.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00003-000/BraTS-GLI-00003-000-t2w.nii.gz
#    creating: /kaggle/working/processed_data/BraTS-GLI-00005-000/
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00005-000/BraTS-GLI-00005-000-seg.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00005-000/BraTS-GLI-00005-000-t1c.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00005-000/BraTS-GLI-00005-000-t1n.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00005-000/BraTS-GLI-00005-000-t2f.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00005-000/BraTS-GLI-00005-000-t2w.nii.gz
#    creating: /kaggle/working/processed_data/BraTS-GLI-00006-000/
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00006-000/BraTS-GLI-00006-000-seg.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00006-000/BraTS-GLI-00006-000-t1c.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00006-000/BraTS-GLI-00006-000-t1n.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00006-000/BraTS-GLI-00006-000-t2f.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00006-000/BraTS-GLI-00006-000-t2w.nii.gz
#    creating: /kaggle/working/processed_data/BraTS-GLI-00008-000/
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00008-000/BraTS-GLI-00008-000-seg.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00008-000/BraTS-GLI-00008-000-t1c.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00008-000/BraTS-GLI-00008-000-t1n.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00008-000/BraTS-GLI-00008-000-t2f.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00008-000/BraTS-GLI-00008-000-t2w.nii.gz
#    creating: /kaggle/working/processed_data/BraTS-GLI-00008-001/
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00008-001/BraTS-GLI-00008-001-seg.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00008-001/BraTS-GLI-00008-001-t1c.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00008-001/BraTS-GLI-00008-001-t1n.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00008-001/BraTS-GLI-00008-001-t2f.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00008-001/BraTS-GLI-00008-001-t2w.nii.gz
#    creating: /kaggle/working/processed_data/BraTS-GLI-00009-000/
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00009-000/BraTS-GLI-00009-000-seg.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00009-000/BraTS-GLI-00009-000-t1c.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00009-000/BraTS-GLI-00009-000-t1n.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00009-000/BraTS-GLI-00009-000-t2f.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00009-000/BraTS-GLI-00009-000-t2w.nii.gz
#    creating: /kaggle/working/processed_data/BraTS-GLI-00009-001/
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00009-001/BraTS-GLI-00009-001-seg.nii.gz
#    creating: /kaggle/working/processed_data/BraTS-GLI-00011-000/
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00011-000/BraTS-GLI-00011-000-seg.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00011-000/BraTS-GLI-00011-000-t1c.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-00011-000/BraTS-GLI-00011-000-t1n.nii.gz
#   inflating: /kaggle/working/processed_data/BraTS-GLI-
000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00138-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00310-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00012-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01534-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01537-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00105-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00157-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-00580-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01131-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01103-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00621-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00481-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00602-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01523-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00751-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-00306-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00324-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00772-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01426-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00837-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01461-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00106-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01109-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00352-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01287-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00024-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00510-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01189-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01409-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01083-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00630-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-01157-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01201-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01017-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01032-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00675-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-00505-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00448-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00350-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00544-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01163-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00834-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00045-001 as it doesn't contain 't2f.nii.gz'
# Deleted /kaggle/working/processed_data/BraTS-GLI-00104-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01019-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00183-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00297-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01265-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00043-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01212-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01068-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00033-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00172-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01078-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00201-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01048-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00453-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00520-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-00071-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00611-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-00064-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01382-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00674-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00217-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00675-001 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01517-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01406-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00124-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01248-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00379-000 as it doesn't contain 't2f.nii.gz'
# Deleted /kaggle/working/processed_data/BraTS-GLI-00604-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-00273-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01447-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01185-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01062-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00477-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-00624-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01510-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00087-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01054-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01213-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01304-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00098-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01449-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00674-001' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00530-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-00020-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01506-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00254-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00431-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01324-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00286-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01335-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00491-001' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00692-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01198-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01354-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01332-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01313-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01117-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00547-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01388-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00051-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00683-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-00048-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00803-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00773-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01243-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00346-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-00796-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00219-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00572-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01478-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00250-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01416-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01143-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01533-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00478-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00760-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01209-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00025-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00386-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00607-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00479-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-00028-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00282-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00714-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00819-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01268-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01238-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00731-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01128-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00212-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01227-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01124-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00230-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01126-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01139-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00645-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01359-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01448-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00613-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00805-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00636-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00128-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00464-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-01151-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00423-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00690-000 as it doesn't contain 't2f.nii.gz'
# Deleted /kaggle/working/processed_data/BraTS-GLI-00732-001 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01266-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00227-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-00733-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01489-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00356-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01300-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01290-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00210-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00121-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00613-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-01659-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00618-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01460-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01371-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-01341-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-00596-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00499-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-00343-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00194-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00222-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-00320-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00195-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00736-001 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01096-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01441-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00663-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01338-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00746-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01305-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01040-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00495-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-00480-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-00416-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00113-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01466-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01190-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01271-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01160-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01211-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01436-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00511-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00030-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01286-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00483-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-00649-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-00402-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01176-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01261-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00528-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00103-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01115-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-01472-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-00792-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00400-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00778-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01270-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-01500-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01502-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00728-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00685-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-00009-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00376-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-01451-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01360-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00820-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00753-001 as it doesn't contain 't2f.nii.gz'
# Deleted /kaggle/working/processed_data/BraTS-GLI-00589-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-00791-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00479-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01372-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00240-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00353-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00656-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00087-001' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-01077-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01099-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00204-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00395-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01197-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00655-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00241-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01529-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-01208-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-00576-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00747-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01437-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01110-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01037-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01522-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-01530-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-00750-001' contains 't2f.nii.gz'.
# 'BraTS-GLI-01312-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-01334-000' contains 't2f.nii.gz'.
# Deleted /kaggle/working/processed_data/BraTS-GLI-00171-000 as it doesn't contain 't2f.nii.gz'
# 'BraTS-GLI-01415-000' contains 't2f.nii.gz'.
# 'BraTS-GLI-00032-001' contains 't2f.nii.gz'.

# %%
import tensorflow as tf

# Dice coefficient for 4 classes
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    total_loss = 0
    for i in range(class_num):
        y_true_f = tf.reshape(y_true[:,:,:,i], [-1])
        y_pred_f = tf.reshape(y_pred[:,:,:,i], [-1])
        intersection = tf.reduce_sum(y_true_f * y_pred_f)
        loss = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)
        total_loss += loss
            
    return total_loss / class_num

# Dice coefficient per class
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = tf.reduce_sum(tf.abs(y_true[:,:,:,1] * y_pred[:,:,:,1]))
    return (2. * intersection) / (tf.reduce_sum(tf.square(y_true[:,:,:,1])) + tf.reduce_sum(tf.square(y_pred[:,:,:,1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = tf.reduce_sum(tf.abs(y_true[:,:,:,2] * y_pred[:,:,:,2]))
    return (2. * intersection) / (tf.reduce_sum(tf.square(y_true[:,:,:,2])) + tf.reduce_sum(tf.square(y_pred[:,:,:,2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = tf.reduce_sum(tf.abs(y_true[:,:,:,3] * y_pred[:,:,:,3]))
    return (2. * intersection) / (tf.reduce_sum(tf.square(y_true[:,:,:,3])) + tf.reduce_sum(tf.square(y_pred[:,:,:,3])) + epsilon)

# Precision
def precision(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    predicted_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_pred, 0, 1)))
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())

# Sensitivity (Recall)
def sensitivity(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    possible_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true, 0, 1)))
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

# Specificity
def specificity(y_true, y_pred):
    true_negatives = tf.reduce_sum(tf.round(tf.clip_by_value((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = tf.reduce_sum(tf.round(tf.clip_by_value(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

# %% [markdown]
# **Modified SANet Model Arch.**
#
# 1. Batch normalization throughout the network
# 2. Residual connections within conv blocks
# 3. Feature Pyramid Network (FPN)
# 4. Channel Attention alongside spatial attention

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, UpSampling2D, Dropout, Input, 
    concatenate, BatchNormalization, GlobalAveragePooling2D, 
    GlobalMaxPooling2D, Reshape, Add, Multiply
)
from tensorflow.keras.models import Model

def enhanced_conv_block(x, filters, ker_init, dropout):
    shortcut = x
    
    # Match channels for residual if needed
    if shortcut.shape[-1] != filters:
        shortcut = Conv2D(filters, 1, padding='same', kernel_initializer=ker_init)(shortcut)
    
    # Main path
    x = Conv2D(filters, 3, padding='same', kernel_initializer=ker_init)(x)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    
    x = Conv2D(filters, 3, padding='same', kernel_initializer=ker_init)(x)
    x = BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    
    # Residual connection
    x = Add()([x, shortcut])
    x = tf.keras.activations.relu(x)
    
    return Dropout(dropout)(x)

def enhanced_attention_block(x, g, inter_channels):
    # Channel attention
    avg_pool = GlobalAveragePooling2D()(x)
    max_pool = GlobalMaxPooling2D()(x)
    
    avg_pool = Reshape((1, 1, inter_channels))(avg_pool)
    max_pool = Reshape((1, 1, inter_channels))(max_pool)
    
    channel_att = Add()([avg_pool, max_pool])
    channel_att = Conv2D(inter_channels, 1)(channel_att)
    channel_att = tf.keras.activations.sigmoid(channel_att)
    
    # Spatial attention with gating signal
    theta_x = Conv2D(inter_channels, 1, strides=1, padding='same')(x)
    phi_g = Conv2D(inter_channels, 1, strides=1, padding='same')(g)
    f = Add()([theta_x, phi_g])
    
    # Refined spatial attention
    f = Conv2D(inter_channels, 1, padding='same')(f)
    f = BatchNormalization()(f)
    f = tf.keras.activations.relu(f)
    spatial_att = Conv2D(1, 1, padding='same')(f)
    spatial_att = tf.keras.activations.sigmoid(spatial_att)
    
    # Apply both attention mechanisms
    x = Multiply()([x, channel_att])
    x = Multiply()([x, spatial_att])
    
    return x

def build_sanet(inputs, ker_init, dropout):
    # Encoder path with enhanced conv blocks
    conv1 = enhanced_conv_block(inputs, 32, ker_init, dropout)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = enhanced_conv_block(pool1, 64, ker_init, dropout)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = enhanced_conv_block(pool2, 128, ker_init, dropout)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = enhanced_conv_block(pool3, 256, ker_init, dropout)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    
    # Bridge
    conv5 = enhanced_conv_block(pool4, 512, ker_init, dropout)
    
    # Decoder path with enhanced attention
    up6 = UpSampling2D(size=(2, 2))(conv5)
    att6 = enhanced_attention_block(conv4, up6, 256)
    merge6 = concatenate([up6, att6])
    conv6 = enhanced_conv_block(merge6, 256, ker_init, dropout)
    
    up7 = UpSampling2D(size=(2, 2))(conv6)
    att7 = enhanced_attention_block(conv3, up7, 128)
    merge7 = concatenate([up7, att7])
    conv7 = enhanced_conv_block(merge7, 128, ker_init, dropout)
    
    up8 = UpSampling2D(size=(2, 2))(conv7)
    att8 = enhanced_attention_block(conv2, up8, 64)
    merge8 = concatenate([up8, att8])
    conv8 = enhanced_conv_block(merge8, 64, ker_init, dropout)
    
    up9 = UpSampling2D(size=(2, 2))(conv8)
    att9 = enhanced_attention_block(conv1, up9, 32)
    merge9 = concatenate([up9, att9])
    conv9 = enhanced_conv_block(merge9, 32, ker_init, dropout)
    
    # Output layer
    outputs = Conv2D(4, (1, 1), activation='softmax')(conv9)
    
    return Model(inputs=inputs, outputs=outputs)

# Define input layer
IMG_SIZE = 128
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

# Build and compile the enhanced SA-Net model
model = build_sanet(input_layer, 'he_normal', 0.2)
model.compile(loss="categorical_crossentropy", 
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
              metrics=['accuracy', 
                       tf.keras.metrics.MeanIoU(num_classes=4), 
                       dice_coef, precision, 
                       sensitivity, specificity, 
                       dice_coef_necrotic, 
                       dice_coef_edema, 
                       dice_coef_enhancing])

# Print model summary
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 2)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 128, 128, 32)   │            608 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 128, 128, 32)   │            128 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 128, 128, 32)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 32)   │          9,248 │ re_lu[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 128, 128, 32)   │            128 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 128, 128, 32)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 128, 128, 32)   │             96 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None,

# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d      │ (None, 256)            │              0 │ dropout_3[0][0]        │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 16, 16, 256)    │              0 │ conv2d_16[0][0],       │
# │                           │                        │                │ conv2d_17[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 1, 1, 256)      │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_1 (Reshape)       │ (None, 1, 1, 256)      │              0 │ global_max_pooling2d[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 16, 16, 256)    │         65,792 │ add_6[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 1, 1, 256)      │              0 │ reshape[0][0],         │
# │                           │                        │                │ reshape_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 16, 16, 256)    │          1,024 │ conv2d_18[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 1, 1, 256)      │         65,792 │ add_5[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_15 (ReLU)           │ (None, 16, 16, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sigmoid (Sigmoid)         │ (None, 1, 1, 256)      │              0 │ conv2d_15[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 16, 16, 1)      │            257 │ re_lu_15[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 16, 16, 256)    │              0 │ dropout_3[0][0],       │
# │                           │                        │                │ sigmoid[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sigmoid_1 (Sigmoid)       │ (None, 16, 16, 1)      │              0 │ conv2d_19[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 16, 16, 256)    │              0 │ multiply[0][0],        │
# │                           │                        │                │ sigmoid_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 16, 16, 768)    │              0 │ up_sampling2d[0][0],   │
# │                           │                        │                │ multiply_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 16, 16, 256)    │      1,769,728 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 16, 16, 256)    │          1,024 │ conv2d_21[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_16 (ReLU)           │ (None, 16, 16, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 16, 16, 256)    │        590,080 │ re_lu_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 16, 16, 256)    │          1,024 │ conv2d_22[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_17 (ReLU)           │ (None, 16, 16, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 16, 16, 256)    │        196,864 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 16, 16, 256)    │              0 │ re_lu_17[0][0],        │
# │                           │                        │                │ conv2d_20[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_18 (ReLU)           │ (None, 16, 16, 256)    │              0 │ add_7[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 16, 16, 256)    │              0 │ re_lu_18[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_1           │ (None, 32, 32, 256)    │              0 │ dropout_5[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 32, 32, 128)    │         16,512 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 32, 32, 128)    │         32,896 │ up_sampling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 128)            │              0 │ dropout_2[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_1    │ (None, 128)            │              0 │ dropout_2[0][0]        │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 32, 32, 128)    │              0 │ conv2d_24[0][0],       │
# │                           │                        │                │ conv2d_25[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_2 (Reshape)       │ (None, 1, 1, 128)      │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_3 (Reshape)       │ (None, 1, 1, 128)      │              0 │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 32, 32, 128)    │         16,512 │ add_9[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 1, 1, 128)      │              0 │ reshape_2[0][0],       │
# │                           │                        │                │ reshape_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 32, 32, 128)    │            512 │ conv2d_26[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 1, 1, 128)      │         16,512 │ add_8[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_19 (ReLU)           │ (None, 32, 32, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sigmoid_2 (Sigmoid)       │ (None, 1, 1, 128)      │              0 │ conv2d_23[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 32, 32, 1)      │            129 │ re_lu_19[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_2 (Multiply)     │ (None, 32, 32, 128)    │              0 │ dropout_2[0][0],       │
# │                           │                        │                │ sigmoid_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sigmoid_3 (Sigmoid)       │ (None, 32, 32, 1)      │              0 │ conv2d_27[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_3 (Multiply)     │ (None, 32, 32, 128)    │              0 │ multiply_2[0][0],      │
# │                           │                        │                │ sigmoid_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 32, 32, 384)    │              0 │ up_sampling2d_1[0][0], │
# │ (Concatenate)             │                        │                │ multiply_3[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_29 (Conv2D)        │ (None, 32, 32, 128)    │        442,496 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 32, 32, 128)    │            512 │ conv2d_29[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_20 (ReLU)           │ (None, 32, 32, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_30 (Conv2D)        │ (None, 32, 32, 128)    │        147,584 │ re_lu_20[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 32, 32, 128)    │            512 │ conv2d_30[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_21 (ReLU)           │ (None, 32, 32, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 32, 32, 128)    │         49,280 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 32, 32, 128)    │              0 │ re_lu_21[0][0],        │
# │                           │                        │                │ conv2d_28[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_22 (ReLU)           │ (None, 32, 32, 128)    │              0 │ add_10[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 32, 32, 128)    │              0 │ re_lu_22[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_2           │ (None, 64, 64, 128)    │              0 │ dropout_6[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_32 (Conv2D)        │ (None, 64, 64, 64)     │          4,160 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_33 (Conv2D)        │ (None, 64, 64, 64)     │          8,256 │ up_sampling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 64)             │              0 │ dropout_1[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_2    │ (None, 64)             │              0 │ dropout_1[0][0]        │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 64, 64, 64)     │              0 │ conv2d_32[0][0],       │
# │                           │                        │                │ conv2d_33[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_4 (Reshape)       │ (None, 1, 1, 64)       │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_5 (Reshape)       │ (None, 1, 1, 64)       │              0 │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_34 (Conv2D)        │ (None, 64, 64, 64)     │          4,160 │ add_12[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 1, 1, 64)       │              0 │ reshape_4[0][0],       │
# │                           │                        │                │ reshape_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 64, 64, 64)     │            256 │ conv2d_34[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_31 (Conv2D)        │ (None, 1, 1, 64)       │          4,160 │ add_11[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_23 (ReLU)           │ (None, 64, 64, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sigmoid_4 (Sigmoid)       │ (None, 1, 1, 64)       │              0 │ conv2d_31[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_35 (Conv2D)        │ (None, 64, 64, 1)      │             65 │ re_lu_23[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_4 (Multiply)     │ (None, 64, 64, 64)     │              0 │ dropout_1[0][0],       │
# │                           │                        │                │ sigmoid_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sigmoid_5 (Sigmoid)       │ (None, 64, 64, 1)      │              0 │ conv2d_35[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_5 (Multiply)     │ (None, 64, 64, 64)     │              0 │ multiply_4[0][0],      │
# │                           │                        │                │ sigmoid_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 64, 64, 192)    │              0 │ up_sampling2d_2[0][0], │
# │ (Concatenate)             │                        │                │ multiply_5[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_37 (Conv2D)        │ (None, 64, 64, 64)     │        110,656 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 64, 64, 64)     │            256 │ conv2d_37[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_24 (ReLU)           │ (None, 64, 64, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_38 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ re_lu_24[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 64, 64, 64)     │            256 │ conv2d_38[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_25 (ReLU)           │ (None, 64, 64, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_36 (Conv2D)        │ (None, 64, 64, 64)     │         12,352 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 64, 64, 64)     │              0 │ re_lu_25[0][0],        │
# │                           │                        │                │ conv2d_36[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_26 (ReLU)           │ (None, 64, 64, 64)     │              0 │ add_13[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 64, 64, 64)     │              0 │ re_lu_26[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_3           │ (None, 128, 128, 64)   │              0 │ dropout_7[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_40 (Conv2D)        │ (None, 128, 128, 32)   │          1,056 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_41 (Conv2D)        │ (None, 128, 128, 32)   │          2,080 │ up_sampling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 32)             │              0 │ dropout[0][0]          │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_3    │ (None, 32)             │              0 │ dropout[0][0]          │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None, 128, 128, 32)   │              0 │ conv2d_40[0][0],       │
# │                           │                        │                │ conv2d_41[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_6 (Reshape)       │ (None, 1, 1, 32)       │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_7 (Reshape)       │ (None, 1, 1, 32)       │              0 │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_42 (Conv2D)        │ (None, 128, 128, 32)   │          1,056 │ add_15[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 1, 1, 32)       │              0 │ reshape_6[0][0],       │
# │                           │                        │                │ reshape_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 128, 128, 32)   │            128 │ conv2d_42[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_39 (Conv2D)        │ (None, 1, 1, 32)       │          1,056 │ add_14[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_27 (ReLU)           │ (None, 128, 128, 32)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sigmoid_6 (Sigmoid)       │ (None, 1, 1, 32)       │              0 │ conv2d_39[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_43 (Conv2D)        │ (None, 128, 128, 1)    │             33 │ re_lu_27[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_6 (Multiply)     │ (None, 128, 128, 32)   │              0 │ dropout[0][0],         │
# │                           │                        │                │ sigmoid_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sigmoid_7 (Sigmoid)       │ (None, 128, 128, 1)    │              0 │ conv2d_43[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_7 (Multiply)     │ (None, 128, 128, 32)   │              0 │ multiply_6[0][0],      │
# │                           │                        │                │ sigmoid_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 128, 128, 96)   │              0 │ up_sampling2d_3[0][0], │
# │ (Concatenate)             │                        │                │ multiply_7[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_45 (Conv2D)        │ (None, 128, 128, 32)   │         27,680 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 128, 128, 32)   │            128 │ conv2d_45[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_28 (ReLU)           │ (None, 128, 128, 32)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_46 (Conv2D)        │ (None, 128, 128, 32)   │          9,248 │ re_lu_28[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 128, 128, 32)   │            128 │ conv2d_46[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_29 (ReLU)           │ (None, 128, 128, 32)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_44 (Conv2D)        │ (None, 128, 128, 32)   │          3,104 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_16 (Add)              │ (None, 128, 128, 32)   │              0 │ re_lu_29[0][0],        │
# │                           │                        │                │ conv2d_44[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_30 (ReLU)           │ (None, 128, 128, 32)   │              0 │ add_16[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_8 (Dropout)       │ (None, 128, 128, 32)   │              0 │ re_lu_30[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_47 (Conv2D)        │ (None, 128, 128, 4)    │            132 │ dropout_8[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 8,734,504 (33.32 MB)
#  Trainable params: 8,727,656 (33.29 MB)
#  Non-trainable params: 6,848 (26.75 KB)

# %%
# lists of directories with studies
TRAIN_DATASET_PATH = "/kaggle/working/processed_data"
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]


def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories); 

    
train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2) 
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
import tensorflow as tf
import numpy as np
import os
import nibabel as nib
import cv2

class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE, IMG_SIZE), batch_size=1, n_channels=2, shuffle=True, **kwargs):
        'Initialization'
        super().__init__(**kwargs)
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.list_IDs) / self.batch_size))  # Use np.ceil to round up

    def __iter__(self):
        while True:
            if self.shuffle:
                self.on_epoch_end()
            for index in range(len(self)):
                yield self.__getitem__(index)

    def __getitem__(self, index):
        indexes = self.indexes[index * self.batch_size: (index + 1) * self.batch_size]
        Batch_ids = [self.list_IDs[k] for k in indexes]
        X, y = self.__data_generation(Batch_ids)
        return X, y

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def load_image_data(self, case_path, img_type):
        data_path = os.path.join(case_path, f'{img_type}.nii.gz')
        try:
            return nib.load(data_path).get_fdata()
        except (FileNotFoundError, nib.filebasedimages.ImageFileError):
            # print(f"Error loading file: {data_path}. Skipping...")
            return None

    def resize_image(self, image, target_size):
        return cv2.resize(image, target_size)

    def zscore_normalize(self, image):
        'Z-score normalization'
        mean = np.mean(image)
        std = np.std(image)
        return (image - mean) / std if std > 0 else image

    def preprocess_image(self, flair, ce):
        flair_normalized = self.zscore_normalize(flair)
        ce_normalized = self.zscore_normalize(ce)

        return flair_normalized, ce_normalized

    def preprocess_segmentation(self, seg):
        'Ensure segmentation values are in the range [0, num_classes - 1]'
        seg = seg.astype(np.uint8)
        seg[seg == 4] = 3  # Adjust tumor labels if necessary
        return seg

    def generate_mask(self, seg):
        mask = tf.one_hot(seg, 4)
        resized_mask = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE))
        return resized_mask

    def __data_generation(self, Batch_ids):
        X = np.zeros((self.batch_size * VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size * VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size * VOLUME_SLICES, *self.dim, 4))

        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)
            flair = self.load_image_data(case_path, f'{i}-t2f')
            ce = self.load_image_data(case_path, f'{i}-t1c')
            seg = self.load_image_data(case_path, f'{i}-seg')

            if flair is None or ce is None or seg is None:
                # print(f"Skipping case {i} due to missing or invalid files.")
                continue

            try:
                seg = self.preprocess_segmentation(seg)
            except Exception as e:
                # print(f"Error preprocessing segmentation for case {i}: {e}")
                continue

            for j in range(VOLUME_SLICES):
                try:
                    flair_slice = self.resize_image(flair[:, :, j + VOLUME_START_AT], self.dim)
                    ce_slice = self.resize_image(ce[:, :, j + VOLUME_START_AT], self.dim)
                    flair_slice, ce_slice = self.preprocess_image(flair_slice, ce_slice)

                    X[j + VOLUME_SLICES * c, :, :, 0] = flair_slice
                    X[j + VOLUME_SLICES * c, :, :, 1] = ce_slice
                    y[j + VOLUME_SLICES * c] = seg[:, :, j + VOLUME_START_AT]
                except Exception as e:
                    # print(f"Error processing slice {j} for case {i}: {e}")
                    continue

        Y = self.generate_mask(y)
        return X, Y


# Example usage
training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau

# Define callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_dice_coef',
        patience=25,  # Increased patience
        restore_best_weights=True,
        mode='max',
        min_delta=1e-4
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_dice_coef',
        factor=0.5,  # Gentler reduction
        patience=10,
        min_lr=1e-6,
        mode='max',
        verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        'best_model_{epoch:02d}_{val_dice_coef:.4f}.keras',
        monitor='val_dice_coef',
        mode='max',
        save_best_only=True,
        verbose=1
    )
]

# Create directories if they don't exist
import os
os.makedirs('models', exist_ok=True)
os.makedirs('logs', exist_ok=True)

# Train the model
history = model.fit(
    training_generator,
    epochs=40,  # Increased max epochs
    callbacks=callbacks,
    validation_data=valid_generator,
    shuffle=True
)
# Out:
# Epoch 1/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9632 - dice_coef: 0.3765 - dice_coef_edema: 0.4760 - dice_coef_enhancing: 0.2142 - dice_coef_necrotic: 0.1555 - loss: 0.2512 - mean_io_u: 0.4849 - precision: 0.9675 - sensitivity: 0.9582 - specificity: 0.9899
# Epoch 1: val_dice_coef improved from -inf to 0.48828, saving model to best_model_01_0.4883.keras
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 883s 1s/step - accuracy: 0.9632 - dice_coef: 0.3765 - dice_coef_edema: 0.4762 - dice_coef_enhancing: 0.2145 - dice_coef_necrotic: 0.1556 - loss: 0.2510 - mean_io_u: 0.4849 - precision: 0.9675 - sensitivity: 0.9582 - specificity: 0.9899 - val_accuracy: 0.9881 - val_dice_coef: 0.4883 - val_dice_coef_edema: 0.6846 - val_dice_coef_enhancing: 0.3738 - val_dice_coef_necrotic: 0.1974 - val_loss: 0.0401 - val_mean_io_u: 0.4998 - val_precision: 0.9884 - val_sensitivity: 0.9872 - val_specificity: 0.9961 - learning_rate: 0.0010
# Epoch 2/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.9903 - dice_coef: 0.5256 - dice_coef_edema: 0.6669 - dice_coef_enhancing: 0.6236 - dice_coef_necrotic: 0.3066 - loss: 0.0285 - mean_io_u: 0.5029 - precision: 0.9921 - sensitivity: 0.9876 - specificity: 0.9973
# Epoch 2: val_dice_coef did not improve from 0.48828
# 746/746 ━━━━━━━━━━━━━━━━━━━━
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 815s 1s/step - accuracy: 0.9948 - dice_coef: 0.7066 - dice_coef_edema: 0.8316 - dice_coef_enhancing: 0.7982 - dice_coef_necrotic: 0.6847 - loss: 0.0158 - mean_io_u: 0.4988 - precision: 0.9948 - sensitivity: 0.9934 - specificity: 0.9982 - val_accuracy: 0.9936 - val_dice_coef: 0.6731 - val_dice_coef_edema: 0.8007 - val_dice_coef_enhancing: 0.7660 - val_dice_coef_necrotic: 0.6351 - val_loss: 0.0198 - val_mean_io_u: 0.5000 - val_precision: 0.9937 - val_sensitivity: 0.9922 - val_specificity: 0.9979 - learning_rate: 0.0010
# Epoch 15/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 784ms/step - accuracy: 0.9953 - dice_coef: 0.7193 - dice_coef_edema: 0.8418 - dice_coef_enhancing: 0.8119 - dice_coef_necrotic: 0.7005 - loss: 0.0141 - mean_io_u: 0.5022 - precision: 0.9952 - sensitivity: 0.9939 - specificity: 0.9984
# Epoch 15: val_dice_coef improved from 0.68609 to 0.68895, saving model to best_model_15_0.6890.keras
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 776s 1s/step - accuracy: 0.9953 - dice_coef: 0.7193 - dice_coef_edema: 0.8418 - dice_coef_enhancing: 0.8118 - dice_coef_necrotic: 0.7005 - loss: 0.0141 - mean_io_u: 0.5022 - precision: 0.9952 - sensitivity: 0.9939 - specificity: 0.9984 - val_accuracy: 0.9933 - val_dice_coef: 0.6890 - val_dice_coef_edema: 0.7846 - val_dice_coef_enhancing: 0.7326 - val_dice_coef_necrotic: 0.6428 - val_loss: 0.0215 - val_mean_io_u: 0.4999 - val_precision: 0.9932 - val_sensitivity: 0.9922 - val_specificity: 0.9977 - learning_rate: 0.0010
# Epoch 16/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - accuracy: 0.9955 - dice_coef: 0.7258 - dice_coef_edema: 0.8457 - dice_coef_enhancing: 0.8188 - dice_coef_necrotic: 0.7030 - loss: 0.0135 - mean_io_u: 0.5011 - precision: 0.9953 - sensitivity: 0.9942 - specificity: 0.9984
# Epoch 16: val_dice_coef did not improve from 0.68895
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 822s 1s/step - accuracy: 0.9955 - dice_coef: 0.7258 - dice_coef_edema: 0.8457 - dice_coef_enhancing: 0.8188 - dice_coef_necrotic: 0.7030 - loss: 0.0135 - mean_io_u: 0.5011 - precision: 0.9953 - sensitivity: 0.9942 - specificity: 0.9984 - val_accuracy: 0.9932 - val_dice_coef: 0.6651 - val_dice_coef_edema: 0.7913 - val_dice_coef_enhancing: 0.7601 - val_dice_coef_necrotic: 0.5726 - val_loss: 0.0213 - val_mean_io_u: 0.4999 - val_precision: 0.9932 - val_sensitivity: 0.9918 - val_specificity: 0.9977 - learning_rate: 0.0010
# Epoch 17/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - accuracy: 0.9953 - dice_coef: 0.7155 - dice_coef_edema: 0.8353 - dice_coef_enhancing: 0.8036 - dice_coef_necrotic: 0.7073 - loss: 0.0141 - mean_io_u: 0.4995 - precision: 0.9953 - sensitivity: 0.9939 - specificity: 0.9984
# Epoch 17: val_dice_coef did not improve from 0.68895
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 810s 1s/step - accuracy: 0.9953 - dice_coef: 0.7155 - dice_coef_edema: 0.8353 - dice_coef_enhancing: 0.8036 - dice_coef_necrotic: 0.7073 - loss: 0.0141 - mean_io_u: 0.4995 - precision: 0.9953 - sensitivity: 0.9939 - specificity: 0.9984 - val_accuracy: 0.9918 - val_dice_coef: 0.6353 - val_dice_coef_edema: 0.7397 - val_dice_coef_enhancing: 0.6480 - val_dice_coef_necrotic: 0.5315 - val_loss: 0.0269 - val_mean_io_u: 0.5000 - val_precision: 0.9920 - val_sensitivity: 0.9908 - val_specificity: 0.9973 - learning_rate: 0.0010
# Epoch 18/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 849ms/step - accuracy: 0.9955 - dice_coef: 0.7275 - dice_coef_edema: 0.8488 - dice_coef_enhancing: 0.8171 - dice_coef_necrotic: 0.7128 - loss: 0.0133 - mean_io_u: 0.5002 - precision: 0.9953 - sensitivity: 0.9942 - specificity: 0.9984
# Epoch 18: val_dice_coef improved from 0.68895 to 0.71401, saving model to best_model_18_0.7140.keras
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 827s 1s/step - accuracy: 0.9955 - dice_coef: 0.7275 - dice_coef_edema: 0.8487 - dice_coef_enhancing: 0.8171 - dice_coef_necrotic: 0.7128 - loss: 0.0133 - mean_io_u: 0.5002 - precision: 0.9953 - sensitivity: 0.9942 - specificity: 0.9984 - val_accuracy: 0.9942 - val_dice_coef: 0.7140 - val_dice_coef_edema: 0.8210 - val_dice_coef_enhancing: 0.7946 - val_dice_coef_necrotic: 0.6775 - val_loss: 0.0187 - val_mean_io_u: 0.5000 - val_precision: 0.9940 - val_sensitivity: 0.9930 - val_specificity: 0.9980 - learning_rate: 0.0010
# Epoch 19/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 851ms/step - accuracy: 0.9956 - dice_coef: 0.7346 - dice_coef_edema: 0.8549 - dice_coef_enhancing: 0.8109 - dice_coef_necrotic: 0.7202 - loss: 0.0129 - mean_io_u: 0.5018 - precision: 0.9954 - sensitivity: 0.9943 - specificity: 0.9984
# Epoch 19: val_dice_coef improved from 0.71401 to 0.71448, saving model to best_model_19_0.7145.keras
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 828s 1s/step - accuracy: 0.9956 - dice_coef: 0.7346 - dice_coef_edema: 0.8548 - dice_coef_enhancing: 0.8109 - dice_coef_necrotic: 0.7202 - loss: 0.0129 - mean_io_u: 0.5018 - precision: 0.9954 - sensitivity: 0.9943 - specificity: 0.9984 - val_accuracy: 0.9939 - val_dice_coef: 0.7145 - val_dice_coef_edema: 0.8104 - val_dice_coef_enhancing: 0.8114 - val_dice_coef_necrotic: 0.6853 - val_loss: 0.0196 - val_mean_io_u: 0.5000 - val_precision: 0.9937 - val_sensitivity: 0.9927 - val_specificity: 0.9979 - learning_rate: 0.0010
# Epoch 20/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.9956 - dice_coef: 0.7463 - dice_coef_edema: 0.8566 - dice_coef_enhancing: 0.8312 - dice_coef_necrotic: 0.7524 - loss: 0.0130 - mean_io_u: 0.5019 - precision: 0.9954 - sensitivity: 0.9943 - specificity: 0.9984
# Epoch 20: val_dice_coef did not improve from 0.71448
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 831s 1s/step - accuracy: 0.9956 - dice_coef: 0.7463 - dice_coef_edema: 0.8566 - dice_coef_enhancing: 0.8312 - dice_coef_necrotic: 0.7524 - loss: 0.0130 - mean_io_u: 0.5019 - precision: 0.9954 - sensitivity: 0.9943 - specificity: 0.9984 - val_accuracy: 0.9937 - val_dice_coef: 0.7069 - val_dice_coef_edema: 0.8186 - val_dice_coef_enhancing: 0.7537 - val_dice_coef_necrotic: 0.6380 - val_loss: 0.0217 - val_mean_io_u: 0.4999 - val_precision: 0.9935 - val_sensitivity: 0.9926 - val_specificity: 0.9978 - learning_rate: 0.0010
# Epoch 21/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.9956 - dice_coef: 0.7353 - dice_coef_edema: 0.8551 - dice_coef_enhancing: 0.8129 - dice_coef_necrotic: 0.7236 - loss: 0.0130 - mean_io_u: 0.5040 - precision: 0.9953 - sensitivity: 0.9943 - specificity: 0.9984
# Epoch 21: val_dice_coef improved from 0.71448 to 0.72086, saving model to best_model_21_0.7209.keras
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 840s 1s/step - accuracy: 0.9956 - dice_coef: 0.7353 - dice_coef_edema: 0.8551 - dice_coef_enhancing: 0.8129 - dice_coef_necrotic: 0.7236 - loss: 0.0130 - mean_io_u: 0.5040 - precision: 0.9953 - sensitivity: 0.9943 - specificity: 0.9984 - val_accuracy: 0.9938 - val_dice_coef: 0.7209 - val_dice_coef_edema: 0.7924 - val_dice_coef_enhancing: 0.7991 - val_dice_coef_necrotic: 0.6582 - val_loss: 0.0223 - val_mean_io_u: 0.4999 - val_precision: 0.9936 - val_sensitivity: 0.9929 - val_specificity: 0.9978 - learning_rate: 0.0010
# Epoch 22/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 848ms/step - accuracy: 0.9960 - dice_coef: 0.7420 - dice_coef_edema: 0.8628 - dice_coef_enhancing: 0.8339 - dice_coef_necrotic: 0.7198 - loss: 0.0117 - mean_io_u: 0.5043 - precision: 0.9957 - sensitivity: 0.9948 - specificity: 0.9986
# Epoch 22: val_dice_coef did not improve from 0.72086
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 824s 1s/step - accuracy: 0.9960 - dice_coef: 0.7420 - dice_coef_edema: 0.8628 - dice_coef_enhancing: 0.8339 - dice_coef_necrotic: 0.7198 - loss: 0.0117 - mean_io_u: 0.5043 - precision: 0.9957 - sensitivity: 0.9948 - specificity: 0.9986 - val_accuracy: 0.9943 - val_dice_coef: 0.7165 - val_dice_coef_edema: 0.8210 - val_dice_coef_enhancing: 0.7973 - val_dice_coef_necrotic: 0.6941 - val_loss: 0.0182 - val_mean_io_u: 0.4999 - val_precision: 0.9941 - val_sensitivity: 0.9931 - val_specificity: 0.9980 - learning_rate: 0.0010
# Epoch 23/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - accuracy: 0.9959 - dice_coef: 0.7469 - dice_coef_edema: 0.8705 - dice_coef_enhancing: 0.8241 - dice_coef_necrotic: 0.7367 - loss: 0.0117 - mean_io_u: 0.5016 - precision: 0.9956 - sensitivity: 0.9947 - specificity: 0.9985
# Epoch 23: val_dice_coef did not improve from 0.72086
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 820s 1s/step - accuracy: 0.9959 - dice_coef: 0.7469 - dice_coef_edema: 0.8705 - dice_coef_enhancing: 0.8241 - dice_coef_necrotic: 0.7367 - loss: 0.0117 - mean_io_u: 0.5016 - precision: 0.9956 - sensitivity: 0.9947 - specificity: 0.9985 - val_accuracy: 0.9925 - val_dice_coef: 0.6710 - val_dice_coef_edema: 0.7830 - val_dice_coef_enhancing: 0.6865 - val_dice_coef_necrotic: 0.5915 - val_loss: 0.0249 - val_mean_io_u: 0.5000 - val_precision: 0.9925 - val_sensitivity: 0.9915 - val_specificity: 0.9975 - learning_rate: 0.0010
# Epoch 24/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9959 - dice_coef: 0.7482 - dice_coef_edema: 0.8669 - dice_coef_enhancing: 0.8222 - dice_coef_necrotic: 0.7432 - loss: 0.0121 - mean_io_u: 0.5034 - precision: 0.9956 - sensitivity: 0.9946 - specificity: 0.9985
# Epoch 24: val_dice_coef did not improve from 0.72086
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 803s 1s/step - accuracy: 0.9959 - dice_coef: 0.7482 - dice_coef_edema: 0.8669 - dice_coef_enhancing: 0.8222 - dice_coef_necrotic: 0.7432 - loss: 0.0121 - mean_io_u: 0.5034 - precision: 0.9956 - sensitivity: 0.9946 - specificity: 0.9985 - val_accuracy: 0.9940 - val_dice_coef: 0.7202 - val_dice_coef_edema: 0.8174 - val_dice_coef_enhancing: 0.8014 - val_dice_coef_necrotic: 0.6627 - val_loss: 0.0214 - val_mean_io_u: 0.5000 - val_precision: 0.9937 - val_sensitivity: 0.9929 - val_specificity: 0.9979 - learning_rate: 0.0010
# Epoch 25/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 831ms/step - accuracy: 0.9960 - dice_coef: 0.7420 - dice_coef_edema: 0.8615 - dice_coef_enhancing: 0.8292 - dice_coef_necrotic: 0.7338 - loss: 0.0121 - mean_io_u: 0.5056 - precision: 0.9957 - sensitivity: 0.9948 - specificity: 0.9985
# Epoch 25: val_dice_coef improved from 0.72086 to 0.73505, saving model to best_model_25_0.7351.keras
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 809s 1s/step - accuracy: 0.9960 - dice_coef: 0.7420 - dice_coef_edema: 0.8615 - dice_coef_enhancing: 0.8292 - dice_coef_necrotic: 0.7338 - loss: 0.0121 - mean_io_u: 0.5056 - precision: 0.9957 - sensitivity: 0.9948 - specificity: 0.9985 - val_accuracy: 0.9943 - val_dice_coef: 0.7351 - val_dice_coef_edema: 0.8259 - val_dice_coef_enhancing: 0.8259 - val_dice_coef_necrotic: 0.6887 - val_loss: 0.0198 - val_mean_io_u: 0.5000 - val_precision: 0.9939 - val_sensitivity: 0.9932 - val_specificity: 0.9979 - learning_rate: 0.0010
# Epoch 26/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.9961 - dice_coef: 0.7497 - dice_coef_edema: 0.8770 - dice_coef_enhancing: 0.8271 - dice_coef_necrotic: 0.7262 - loss: 0.0116 - mean_io_u: 0.5029 - precision: 0.9957 - sensitivity: 0.9949 - specificity: 0.9986
# Epoch 26: val_dice_coef did not improve from 0.73505
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 821s 1s/step - accuracy: 0.9961 - dice_coef: 0.7497 - dice_coef_edema: 0.8770 - dice_coef_enhancing: 0.8271 - dice_coef_necrotic: 0.7262 - loss: 0.0116 - mean_io_u: 0.5029 - precision: 0.9957 - sensitivity: 0.9949 - specificity: 0.9986 - val_accuracy: 0.9945 - val_dice_coef: 0.7322 - val_dice_coef_edema: 0.8323 - val_dice_coef_enhancing: 0.8161 - val_dice_coef_necrotic: 0.6712 - val_loss: 0.0196 - val_mean_io_u: 0.4998 - val_precision: 0.9942 - val_sensitivity: 0.9934 - val_specificity: 0.9980 - learning_rate: 0.0010
# Epoch 27/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 840ms/step - accuracy: 0.9962 - dice_coef: 0.7595 - dice_coef_edema: 0.8717 - dice_coef_enhancing: 0.8266 - dice_coef_necrotic: 0.7704 - loss: 0.0108 - mean_io_u: 0.5067 - precision: 0.9959 - sensitivity: 0.9950 - specificity: 0.9986
# Epoch 27: val_dice_coef did not improve from 0.73505
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 817s 1s/step - accuracy: 0.9962 - dice_coef: 0.7595 - dice_coef_edema: 0.8717 - dice_coef_enhancing: 0.8266 - dice_coef_necrotic: 0.7704 - loss: 0.0108 - mean_io_u: 0.5067 - precision: 0.9959 - sensitivity: 0.9950 - specificity: 0.9986 - val_accuracy: 0.9937 - val_dice_coef: 0.7121 - val_dice_coef_edema: 0.8118 - val_dice_coef_enhancing: 0.7638 - val_dice_coef_necrotic: 0.6508 - val_loss: 0.0225 - val_mean_io_u: 0.4999 - val_precision: 0.9935 - val_sensitivity: 0.9926 - val_specificity: 0.9978 - learning_rate: 0.0010
# Epoch 28/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 833ms/step - accuracy: 0.9962 - dice_coef: 0.7551 - dice_coef_edema: 0.8802 - dice_coef_enhancing: 0.8288 - dice_coef_necrotic: 0.7464 - loss: 0.0108 - mean_io_u: 0.5041 - precision: 0.9959 - sensitivity: 0.9951 - specificity: 0.9986
# Epoch 28: val_dice_coef did not improve from 0.73505
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 809s 1s/step - accuracy: 0.9962 - dice_coef: 0.7551 - dice_coef_edema: 0.8802 - dice_coef_enhancing: 0.8288 - dice_coef_necrotic: 0.7464 - loss: 0.0108 - mean_io_u: 0.5041 - precision: 0.9959 - sensitivity: 0.9951 - specificity: 0.9986 - val_accuracy: 0.9943 - val_dice_coef: 0.7350 - val_dice_coef_edema: 0.8326 - val_dice_coef_enhancing: 0.8025 - val_dice_coef_necrotic: 0.6970 - val_loss: 0.0193 - val_mean_io_u: 0.4999 - val_precision: 0.9940 - val_sensitivity: 0.9932 - val_specificity: 0.9980 - learning_rate: 0.0010
# Epoch 29/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.9963 - dice_coef: 0.7605 - dice_coef_edema: 0.8808 - dice_coef_enhancing: 0.8340 - dice_coef_necrotic: 0.7580 - loss: 0.0107 - mean_io_u: 0.5058 - precision: 0.9959 - sensitivity: 0.9951 - specificity: 0.9986
# Epoch 29: val_dice_coef did not improve from 0.73505
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 817s 1s/step - accuracy: 0.9963 - dice_coef: 0.7605 - dice_coef_edema: 0.8808 - dice_coef_enhancing: 0.8340 - dice_coef_necrotic: 0.7580 - loss: 0.0107 - mean_io_u: 0.5058 - precision: 0.9959 - sensitivity: 0.9951 - specificity: 0.9986 - val_accuracy: 0.9940 - val_dice_coef: 0.7323 - val_dice_coef_edema: 0.8151 - val_dice_coef_enhancing: 0.8035 - val_dice_coef_necrotic: 0.6824 - val_loss: 0.0219 - val_mean_io_u: 0.4999 - val_precision: 0.9937 - val_sensitivity: 0.9930 - val_specificity: 0.9979 - learning_rate: 0.0010
# Epoch 30/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.9963 - dice_coef: 0.7659 - dice_coef_edema: 0.8796 - dice_coef_enhancing: 0.8407 - dice_coef_necrotic: 0.7640 - loss: 0.0108 - mean_io_u: 0.5062 - precision: 0.9959 - sensitivity: 0.9951 - specificity: 0.9986
# Epoch 30: val_dice_coef did not improve from 0.73505
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 822s 1s/step - accuracy: 0.9963 - dice_coef: 0.7659 - dice_coef_edema: 0.8796 - dice_coef_enhancing: 0.8407 - dice_coef_necrotic: 0.7640 - loss: 0.0108 - mean_io_u: 0.5061 - precision: 0.9959 - sensitivity: 0.9951 - specificity: 0.9986 - val_accuracy: 0.9942 - val_dice_coef: 0.7307 - val_dice_coef_edema: 0.8238 - val_dice_coef_enhancing: 0.8086 - val_dice_coef_necrotic: 0.6899 - val_loss: 0.0195 - val_mean_io_u: 0.4999 - val_precision: 0.9939 - val_sensitivity: 0.9931 - val_specificity: 0.9979 - learning_rate: 0.0010
# Epoch 31/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 796ms/step - accuracy: 0.9965 - dice_coef: 0.7662 - dice_coef_edema: 0.8860 - dice_coef_enhancing: 0.8496 - dice_coef_necrotic: 0.7579 - loss: 0.0101 - mean_io_u: 0.5061 - precision: 0.9961 - sensitivity: 0.9954 - specificity: 0.9987
# Epoch 31: val_dice_coef improved from 0.73505 to 0.73543, saving model to best_model_31_0.7354.keras
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 781s 1s/step - accuracy: 0.9965 - dice_coef: 0.7662 - dice_coef_edema: 0.8860 - dice_coef_enhancing: 0.8496 - dice_coef_necrotic: 0.7580 - loss: 0.0101 - mean_io_u: 0.5061 - precision: 0.9961 - sensitivity: 0.9954 - specificity: 0.9987 - val_accuracy: 0.9944 - val_dice_coef: 0.7354 - val_dice_coef_edema: 0.8282 - val_dice_coef_enhancing: 0.8149 - val_dice_coef_necrotic: 0.7129 - val_loss: 0.0195 - val_mean_io_u: 0.4999 - val_precision: 0.9941 - val_sensitivity: 0.9933 - val_specificity: 0.9980 - learning_rate: 0.0010
# Epoch 32/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - accuracy: 0.9965 - dice_coef: 0.7724 - dice_coef_edema: 0.8899 - dice_coef_enhancing: 0.8551 - dice_coef_necrotic: 0.7659 - loss: 0.0102 - mean_io_u: 0.5066 - precision: 0.9960 - sensitivity: 0.9953 - specificity: 0.9987
# Epoch 32: val_dice_coef improved from 0.73543 to 0.74680, saving model to best_model_32_0.7468.keras
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 755s 1s/step - accuracy: 0.9965 - dice_coef: 0.7724 - dice_coef_edema: 0.8898 - dice_coef_enhancing: 0.8551 - dice_coef_necrotic: 0.7659 - loss: 0.0102 - mean_io_u: 0.5066 - precision: 0.9960 - sensitivity: 0.9953 - specificity: 0.9987 - val_accuracy: 0.9945 - val_dice_coef: 0.7468 - val_dice_coef_edema: 0.8299 - val_dice_coef_enhancing: 0.8375 - val_dice_coef_necrotic: 0.7144 - val_loss: 0.0195 - val_mean_io_u: 0.4999 - val_precision: 0.9941 - val_sensitivity: 0.9934 - val_specificity: 0.9980 - learning_rate: 0.0010
# Epoch 33/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 840ms/step - accuracy: 0.9966 - dice_coef: 0.7698 - dice_coef_edema: 0.8918 - dice_coef_enhancing: 0.8466 - dice_coef_necrotic: 0.7600 - loss: 0.0098 - mean_io_u: 0.5081 - precision: 0.9961 - sensitivity: 0.9955 - specificity: 0.9987
# Epoch 33: val_dice_coef did not improve from 0.74680
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 815s 1s/step - accuracy: 0.9966 - dice_coef: 0.7698 - dice_coef_edema: 0.8917 - dice_coef_enhancing: 0.8466 - dice_coef_necrotic: 0.7600 - loss: 0.0098 - mean_io_u: 0.5081 - precision: 0.9961 - sensitivity: 0.9955 - specificity: 0.9987 - val_accuracy: 0.9943 - val_dice_coef: 0.7311 - val_dice_coef_edema: 0.8302 - val_dice_coef_enhancing: 0.8073 - val_dice_coef_necrotic: 0.6896 - val_loss: 0.0200 - val_mean_io_u: 0.4999 - val_precision: 0.9941 - val_sensitivity: 0.9931 - val_specificity: 0.9980 - learning_rate: 0.0010
# Epoch 34/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.9967 - dice_coef: 0.7813 - dice_coef_edema: 0.8953 - dice_coef_enhancing: 0.8596 - dice_coef_necrotic: 0.7863 - loss: 0.0095 - mean_io_u: 0.5045 - precision: 0.9962 - sensitivity: 0.9955 - specificity: 0.9987
# Epoch 34: val_dice_coef improved from 0.74680 to 0.75053, saving model to best_model_34_0.7505.keras
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 800s 1s/step - accuracy: 0.9967 - dice_coef: 0.7813 - dice_coef_edema: 0.8953 - dice_coef_enhancing: 0.8595 - dice_coef_necrotic: 0.7863 - loss: 0.0095 - mean_io_u: 0.5045 - precision: 0.9962 - sensitivity: 0.9955 - specificity: 0.9987 - val_accuracy: 0.9945 - val_dice_coef: 0.7505 - val_dice_coef_edema: 0.8319 - val_dice_coef_enhancing: 0.8438 - val_dice_coef_necrotic: 0.7103 - val_loss: 0.0190 - val_mean_io_u: 0.4998 - val_precision: 0.9942 - val_sensitivity: 0.9935 - val_specificity: 0.9980 - learning_rate: 0.0010
# Epoch 35/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.9968 - dice_coef: 0.7773 - dice_coef_edema: 0.8993 - dice_coef_enhancing: 0.8519 - dice_coef_necrotic: 0.7623 - loss: 0.0093 - mean_io_u: 0.5076 - precision: 0.9963 - sensitivity: 0.9956 - specificity: 0.9987
# Epoch 35: val_dice_coef did not improve from 0.75053
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 816s 1s/step - accuracy: 0.9968 - dice_coef: 0.7773 - dice_coef_edema: 0.8993 - dice_coef_enhancing: 0.8519 - dice_coef_necrotic: 0.7623 - loss: 0.0093 - mean_io_u: 0.5076 - precision: 0.9963 - sensitivity: 0.9956 - specificity: 0.9987 - val_accuracy: 0.9942 - val_dice_coef: 0.7457 - val_dice_coef_edema: 0.8201 - val_dice_coef_enhancing: 0.8125 - val_dice_coef_necrotic: 0.7077 - val_loss: 0.0215 - val_mean_io_u: 0.4999 - val_precision: 0.9939 - val_sensitivity: 0.9933 - val_specificity: 0.9980 - learning_rate: 0.0010
# Epoch 36/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 833ms/step - accuracy: 0.9968 - dice_coef: 0.7864 - dice_coef_edema: 0.9021 - dice_coef_enhancing: 0.8622 - dice_coef_necrotic: 0.7826 - loss: 0.0093 - mean_io_u: 0.5068 - precision: 0.9962 - sensitivity: 0.9956 - specificity: 0.9987
# Epoch 36: val_dice_coef did not improve from 0.75053
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 811s 1s/step - accuracy: 0.9968 - dice_coef: 0.7864 - dice_coef_edema: 0.9021 - dice_coef_enhancing: 0.8622 - dice_coef_necrotic: 0.7826 - loss: 0.0093 - mean_io_u: 0.5068 - precision: 0.9962 - sensitivity: 0.9956 - specificity: 0.9987 - val_accuracy: 0.9945 - val_dice_coef: 0.7465 - val_dice_coef_edema: 0.8344 - val_dice_coef_enhancing: 0.8303 - val_dice_coef_necrotic: 0.7041 - val_loss: 0.0208 - val_mean_io_u: 0.4998 - val_precision: 0.9941 - val_sensitivity: 0.9935 - val_specificity: 0.9980 - learning_rate: 0.0010
# Epoch 37/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 826ms/step - accuracy: 0.9968 - dice_coef: 0.7825 - dice_coef_edema: 0.8964 - dice_coef_enhancing: 0.8528 - dice_coef_necrotic: 0.7923 - loss: 0.0092 - mean_io_u: 0.5091 - precision: 0.9963 - sensitivity: 0.9957 - specificity: 0.9987
# Epoch 37: val_dice_coef did not improve from 0.75053
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 806s 1s/step - accuracy: 0.9968 - dice_coef: 0.7825 - dice_coef_edema: 0.8964 - dice_coef_enhancing: 0.8528 - dice_coef_necrotic: 0.7923 - loss: 0.0092 - mean_io_u: 0.5091 - precision: 0.9963 - sensitivity: 0.9957 - specificity: 0.9987 - val_accuracy: 0.9943 - val_dice_coef: 0.7270 - val_dice_coef_edema: 0.8322 - val_dice_coef_enhancing: 0.8023 - val_dice_coef_necrotic: 0.6898 - val_loss: 0.0196 - val_mean_io_u: 0.4998 - val_precision: 0.9939 - val_sensitivity: 0.9931 - val_specificity: 0.9980 - learning_rate: 0.0010
# Epoch 38/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.9967 - dice_coef: 0.7808 - dice_coef_edema: 0.8932 - dice_coef_enhancing: 0.8574 - dice_coef_necrotic: 0.7843 - loss: 0.0094 - mean_io_u: 0.5058 - precision: 0.9962 - sensitivity: 0.9956 - specificity: 0.9987
# Epoch 38: val_dice_coef did not improve from 0.75053
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 815s 1s/step - accuracy: 0.9967 - dice_coef: 0.7808 - dice_coef_edema: 0.8932 - dice_coef_enhancing: 0.8574 - dice_coef_necrotic: 0.7843 - loss: 0.0094 - mean_io_u: 0.5058 - precision: 0.9962 - sensitivity: 0.9956 - specificity: 0.9987 - val_accuracy: 0.9935 - val_dice_coef: 0.7226 - val_dice_coef_edema: 0.7726 - val_dice_coef_enhancing: 0.7983 - val_dice_coef_necrotic: 0.6627 - val_loss: 0.0245 - val_mean_io_u: 0.4997 - val_precision: 0.9934 - val_sensitivity: 0.9926 - val_specificity: 0.9978 - learning_rate: 0.0010
# Epoch 39/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.9967 - dice_coef: 0.7752 - dice_coef_edema: 0.8909 - dice_coef_enhancing: 0.8483 - dice_coef_necrotic: 0.7654 - loss: 0.0094 - mean_io_u: 0.5071 - precision: 0.9962 - sensitivity: 0.9956 - specificity: 0.9987
# Epoch 39: val_dice_coef did not improve from 0.75053
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 812s 1s/step - accuracy: 0.9967 - dice_coef: 0.7752 - dice_coef_edema: 0.8909 - dice_coef_enhancing: 0.8484 - dice_coef_necrotic: 0.7654 - loss: 0.0094 - mean_io_u: 0.5071 - precision: 0.9962 - sensitivity: 0.9956 - specificity: 0.9987 - val_accuracy: 0.9942 - val_dice_coef: 0.7417 - val_dice_coef_edema: 0.8306 - val_dice_coef_enhancing: 0.8031 - val_dice_coef_necrotic: 0.6942 - val_loss: 0.0209 - val_mean_io_u: 0.4998 - val_precision: 0.9939 - val_sensitivity: 0.9933 - val_specificity: 0.9979 - learning_rate: 0.0010
# Epoch 40/40
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.9968 - dice_coef: 0.7911 - dice_coef_edema: 0.9027 - dice_coef_enhancing: 0.8601 - dice_coef_necrotic: 0.8040 - loss: 0.0092 - mean_io_u: 0.5063 - precision: 0.9963 - sensitivity: 0.9956 - specificity: 0.9987
# Epoch 40: val_dice_coef did not improve from 0.75053
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 812s 1s/step - accuracy: 0.9968 - dice_coef: 0.7911 - dice_coef_edema: 0.9028 - dice_coef_enhancing: 0.8601 - dice_coef_necrotic: 0.8040 - loss: 0.0092 - mean_io_u: 0.5063 - precision: 0.9963 - sensitivity: 0.9956 - specificity: 0.9987 - val_accuracy: 0.9944 - val_dice_coef: 0.7487 - val_dice_coef_edema: 0.8334 - val_dice_coef_enhancing: 0.8227 - val_dice_coef_necrotic: 0.7141 - val_loss: 0.0208 - val_mean_io_u: 0.4998 - val_precision: 0.9941 - val_sensitivity: 0.9935 - val_specificity: 0.9980 - learning_rate: 0.0010

# %%
test_metrics = model.evaluate(test_generator, verbose=1)

# Metrics names corresponding to the evaluation metrics
metrics_names = [
    "Loss", "Accuracy", "Mean IoU", "Dice Coefficient",
    "Precision", "Sensitivity (Recall)", "Specificity",
    "Dice Coef - Necrotic", "Dice Coef - Edema", "Dice Coef - Enhancing"
]

# Print the evaluation results
print("Evaluation Results:")
for name, value in zip(metrics_names, test_metrics):
    print(f"{name}: {value:.4f}")

# Visualization: Bar Chart of Evaluation Metrics
def plot_evaluation_bar_chart(metrics_names, metrics_values):
    plt.figure(figsize=(10, 6))
    y_pos = np.arange(len(metrics_names))

    plt.barh(y_pos, metrics_values, alpha=0.8, color='skyblue', edgecolor='black')
    plt.yticks(y_pos, metrics_names)
    plt.xlabel("Metric Value")
    plt.title("Evaluation Metrics")
    
    # Adding value labels
    for i, v in enumerate(metrics_values):
        plt.text(v + 0.01, i, f"{v:.4f}", va='center', fontsize=10)

    plt.tight_layout()
    plt.show()

# Plot the metrics
plot_evaluation_bar_chart(metrics_names, test_metrics)
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 112s 844ms/step - accuracy: 0.9948 - dice_coef: 0.7454 - dice_coef_edema: 0.8190 - dice_coef_enhancing: 0.8102 - dice_coef_necrotic: 0.7255 - loss: 0.0171 - mean_io_u: 0.5589 - precision: 0.9944 - sensitivity: 0.9937 - specificity: 0.9981
# Evaluation Results:
# Loss: 0.0186
# Accuracy: 0.9946
# Mean IoU: 0.5000
# Dice Coefficient: 0.7398
# Precision: 0.9942
# Sensitivity (Recall): 0.9936
# Specificity: 0.9981
# Dice Coef - Necrotic: 0.7078
# Dice Coef - Edema: 0.8194
# Dice Coef - Enhancing: 0.8036

# %%
import pickle

# Save the history object using pickle
with open('ModifiedSANet_model.pkl', 'wb') as f:
    pickle.dump(history.history, f)

print("ModifiedSANet_history saved successfully.")
# Out:
# ModifiedSANet_history saved successfully.

# %%
# Load the history object
with open('ModifiedSANet_model.pkl', 'rb') as f:
    loaded_history = pickle.load(f)

print("ModifiedSANet_history loaded successfully.")
# Out:
# ModifiedSANet_history loaded successfully.

# %%
loaded_history.keys()
# Out:
# dict_keys(['accuracy', 'dice_coef', 'dice_coef_edema', 'dice_coef_enhancing', 'dice_coef_necrotic', 'loss', 'mean_io_u', 'precision', 'sensitivity', 'specificity', 'val_accuracy', 'val_dice_coef', 'val_dice_coef_edema', 'val_dice_coef_enhancing', 'val_dice_coef_necrotic', 'val_loss', 'val_mean_io_u', 'val_precision', 'val_sensitivity', 'val_specificity', 'learning_rate'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

acc = loaded_history['accuracy']
val_acc = loaded_history['val_accuracy']
epochs = range(len(acc))

fig = plt.figure(figsize=(7,4))

# Set the linewidth to a smaller value (e.g., 2)
plt.plot(epochs, acc, 'r', label="Training Accuracy", linewidth=2)
plt.plot(epochs, val_acc, 'b', label="Validation Accuracy", linewidth=2)

# Adjust the legend font size
plt.legend(loc='lower right', fontsize=8)  # Set fontsize to your preference

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss = loaded_history['loss']
val_loss = loaded_history['val_loss']
epochs = range(len(loss))

fig = plt.figure(figsize=(7,4))

# Set the linewidth to a smaller value (e.g., 2)
plt.plot(epochs, loss, 'r', label="Training loss", linewidth=2)
plt.plot(epochs, val_loss, 'b', label="Validation loss", linewidth=2)

# Adjust the legend font size
plt.legend(loc='upper right', fontsize=8)  # Set fontsize to your preference

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Extract the required metrics from the history dictionary
dice_coef = loaded_history['dice_coef']
val_dice_coef = loaded_history['val_dice_coef']
dice_coef_edema = loaded_history['dice_coef_edema']
val_dice_coef_edema = loaded_history['val_dice_coef_edema']
dice_coef_enhancing = loaded_history['dice_coef_enhancing']
val_dice_coef_enhancing = loaded_history['val_dice_coef_enhancing']
dice_coef_necrotic = loaded_history['dice_coef_necrotic']
val_dice_coef_necrotic = loaded_history['val_dice_coef_necrotic']

epochs = range(len(dice_coef))  # assuming all metrics have the same length

# Set up the figure
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Plot for dice_coef
axs[0, 0].plot(epochs, dice_coef, 'r', label="Training Dice Coefficient", linewidth=2)
axs[0, 0].plot(epochs, val_dice_coef, 'b', label="Validation Dice Coefficient", linewidth=2)
axs[0, 0].set_title("Dice Coefficient")
#axs[0, 0].set_ylim(0, 2) 
axs[0, 0].legend(loc='lower right', fontsize=8)

# Plot for dice_coef_edema
axs[0, 1].plot(epochs, dice_coef_edema, 'r', label="Training Dice Coefficient (Edema)", linewidth=2)
axs[0, 1].plot(epochs, val_dice_coef_edema, 'b', label="Validation Dice Coefficient (Edema)", linewidth=2)
axs[0, 1].set_title("Dice Coefficient (Edema)")
#axs[0, 1].set_ylim(0, 2) 
axs[0, 1].legend(loc='lower right', fontsize=8)

# Plot for dice_coef_enhancing
axs[1, 0].plot(epochs, dice_coef_enhancing, 'r', label="Training Dice Coefficient (Enhancing)", linewidth=2)
axs[1, 0].plot(epochs, val_dice_coef_enhancing, 'b', label="Validation Dice Coefficient (Enhancing)", linewidth=2)
axs[1, 0].set_title("Dice Coefficient (Enhancing)")
#axs[1, 0].set_ylim(0, 2) 
axs[1, 0].legend(loc='lower right', fontsize=8)

# Plot for dice_coef_necrotic
axs[1, 1].plot(epochs, dice_coef_necrotic, 'r', label="Training Dice Coefficient (Necrotic)", linewidth=2)
axs[1, 1].plot(epochs, val_dice_coef_necrotic, 'b', label="Validation Dice Coefficient (Necrotic)", linewidth=2)
axs[1, 1].set_title("Dice Coefficient (Necrotic)")
#axs[1, 1].set_ylim(0, 2) 
axs[1, 1].legend(loc='lower right', fontsize=8)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract metrics from the history dictionary (training values only)
dice_coef = loaded_history['dice_coef']
dice_coef_edema = loaded_history['dice_coef_edema']
dice_coef_enhancing = loaded_history['dice_coef_enhancing']
dice_coef_necrotic = loaded_history['dice_coef_necrotic']

epochs = range(len(dice_coef))  # assuming all metrics have the same length

# Set up the figure
plt.figure(figsize=(12, 6))

# Plot all dice coefficients with their respective colors
plt.plot(epochs, dice_coef, label="Dice Coefficient", linewidth=2, color='red')
plt.plot(epochs, dice_coef_edema, label="Dice Coefficient (Edema)", linewidth=2, color='green')
plt.plot(epochs, dice_coef_enhancing, label="Dice Coefficient (Enhancing)", linewidth=2, color='blue')
plt.plot(epochs, dice_coef_necrotic, label="Dice Coefficient (Necrotic)", linewidth=2, color='purple')

# Annotate the highest peak for each metric with a filled color ball
def annotate_peak_with_ball(metric, color, label):
    peak_value = max(metric)
    peak_epoch = metric.index(peak_value)
    plt.scatter(peak_epoch, peak_value, color=color, s=50, zorder=5)  # Plot color-filled ball
    plt.text(peak_epoch + 5, peak_value - 0.05, f'{label}: {peak_value:.2f}', fontsize=10, color=color)

# Annotating each metric's highest peak with a color-filled ball
annotate_peak_with_ball(dice_coef, 'red', "Dice Coefficient")
annotate_peak_with_ball(dice_coef_edema, 'green', "Dice Coefficient (Edema)")
annotate_peak_with_ball(dice_coef_enhancing, 'blue', "Dice Coefficient (Enhancing)")
annotate_peak_with_ball(dice_coef_necrotic, 'purple', "Dice Coefficient (Necrotic)")

# Add titles and labels
plt.title("Comparison of Dice Coefficients with Highest Peaks", fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Dice Coefficient', fontsize=12)

# Adjust the y-axis range to be from 0 to 1
plt.ylim(0, 1)

# Display legend
plt.legend(loc='lower right', fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract validation metrics from the history dictionary
val_dice_coef = loaded_history['val_dice_coef']
val_dice_coef_edema = loaded_history['val_dice_coef_edema']
val_dice_coef_enhancing = loaded_history['val_dice_coef_enhancing']
val_dice_coef_necrotic = loaded_history['val_dice_coef_necrotic']

epochs = range(len(val_dice_coef))  # assuming all metrics have the same length

# Set up the figure
plt.figure(figsize=(12, 6))

# Plot only validation dice coefficients
line_width = 2
plt.plot(epochs, val_dice_coef, label="Dice Coefficient (Validation)", linewidth=line_width, color='red')
plt.plot(epochs, val_dice_coef_edema, label="Dice Coefficient (Edema - Validation)", linewidth=line_width, color='green')
plt.plot(epochs, val_dice_coef_enhancing, label="Dice Coefficient (Enhancing - Validation)", linewidth=line_width, color='blue')
plt.plot(epochs, val_dice_coef_necrotic, label="Dice Coefficient (Necrotic - Validation)", linewidth=line_width, color='purple')

# Annotate the highest peak for each validation metric with a smaller color-filled ball
def annotate_peak_with_ball(metric, color, label):
    peak_value = max(metric)
    peak_epoch = metric.index(peak_value)
    plt.scatter(peak_epoch, peak_value, color=color, s=30, zorder=5)  # Smaller size for color-filled ball
    return peak_epoch, peak_value, label, color

# Annotating each validation metric's highest peak
annotations = [
    annotate_peak_with_ball(val_dice_coef, 'red', "Dice Coefficient (Validation)"),
    annotate_peak_with_ball(val_dice_coef_edema, 'green', "Dice Coefficient (Edema - Validation)"),
    annotate_peak_with_ball(val_dice_coef_enhancing, 'blue', "Dice Coefficient (Enhancing - Validation)"),
    annotate_peak_with_ball(val_dice_coef_necrotic, 'purple', "Dice Coefficient (Necrotic - Validation)")
]

# Position for text outside the plot (adjusting this to place text together)
text_offset_x = 1.02  # To move text outside the plot area on the x-axis
text_offset_y = 0.5   # Vertical offset to position text without overlap

# Add titles and labels
plt.title("Comparison of Dice Coefficients (Validation) with Highest Peaks", fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Dice Coefficient', fontsize=12)

# Adjust the y-axis range to be from 0 to 1
plt.ylim(0, 1)

# Display legend
plt.legend(loc='lower right', fontsize=10)

# Place text annotations outside the plot area
for i, (peak_epoch, peak_value, label, color) in enumerate(annotations):
    # Position the text outside the plot area on the right side
    plt.text(text_offset_x, text_offset_y - i * 0.1, f'{label}: {peak_value:.2f}', fontsize=10, color=color, transform=plt.gca().transAxes)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to visualize the random masks and their predictions
def visualize_random_masks(generator, model, num_samples):
    # Randomly select 'num_samples' indices from the generator
    random_indices = np.random.choice(len(generator), size=num_samples, replace=False)
    
    # Adjust figure size for better layout when displaying 100 images
    plt.figure(figsize=(20, num_samples * 2))  # Adjusting the height for 100 samples
    
    for idx, random_index in enumerate(random_indices):
        # Get the batch of data for the current index
        X, Y = generator[random_index]  # X: input, Y: original mask (segmentation mask)

        # Take the first sample from the batch and the first slice
        original_mask = Y[0, :, :, 0]  # Original mask (assuming single channel output for the mask)

        # Take the first slice of the input image (e.g., 128x128 image with 2 channels)
        X_slice = X[0, :, :, :]  # Choose the first image slice from the batch

        # Generate the prediction from the model
        predicted_mask = model.predict(X_slice[None, :, :, :])[0]  # Adding the batch dimension

        # Assuming that predicted_mask is a one-hot encoded mask, we need to take the argmax to get the predicted class
        predicted_mask = np.argmax(predicted_mask, axis=-1)  # Convert to single class prediction (class with max value)

        # Plot original mask and predicted mask side by side
        ax = plt.subplot(num_samples, 2, idx * 2 + 1)
        ax.set_title(f"Original Mask {idx+1}", fontsize=10)
        ax.imshow(original_mask, cmap='gray')
        ax.axis('off')

        ax = plt.subplot(num_samples, 2, idx * 2 + 2)
        ax.set_title(f"Predicted Mask {idx+1}", fontsize=10)
        ax.imshow(predicted_mask, cmap='gray')
        ax.axis('off')
    
    plt.tight_layout()
    plt.show()

# Example usage
visualize_random_masks(test_generator, model, num_samples=20)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

def plot_training_history_enhanced(history, metrics):
    """
    Plots the metrics and loss over epochs from the training history with enhancements.

    :param history: The History object returned by model.fit().
    :param metrics: List of metric names to plot (e.g., ['accuracy', 'loss']).
    """
    num_metrics = len(metrics)
    fig, axes = plt.subplots(nrows=num_metrics, ncols=1, figsize=(10, 5 * num_metrics))
    if num_metrics == 1:
        axes = [axes]  # Ensure axes is iterable for a single metric
    
    for i, metric in enumerate(metrics):
        ax = axes[i]
        if metric in history.history:
            ax.plot(history.history[metric], label=f'Train {metric}', marker='o', linestyle='-')
            if f'val_{metric}' in history.history:
                ax.plot(history.history[f'val_{metric}'], label=f'Validation {metric}', marker='s', linestyle='--')
            
            # Highlight the best epoch for validation metric
            if f'val_{metric}' in history.history:
                best_epoch = np.argmax(history.history[f'val_{metric}'])
                best_value = history.history[f'val_{metric}'][best_epoch]
                ax.scatter(best_epoch, best_value, color='red', label=f'Best Val {metric} ({best_value:.3f})')
                ax.annotate(f"{best_value:.3f}", (best_epoch, best_value),
                            textcoords="offset points", xytext=(-15, 10), ha='center', fontsize=10, color='red')
        
        ax.set_title(f'{metric.capitalize()} Over Epochs', fontsize=16)
        ax.set_xlabel('Epochs', fontsize=14)
        ax.set_ylabel(metric.capitalize(), fontsize=14)
        ax.legend(fontsize=12)
        ax.grid(True)
    
    plt.tight_layout()
    plt.show()

def plot_metric_vs_metric(history, metric_pairs):
    """
    Plots one metric against another to visualize their relationship.

    :param history: The History object returned by model.fit().
    :param metric_pairs: List of tuples containing pairs of metrics to plot (e.g., [('accuracy', 'loss')]).
    """
    num_pairs = len(metric_pairs)
    fig, axes = plt.subplots(nrows=num_pairs, ncols=1, figsize=(10, 5 * num_pairs))
    if num_pairs == 1:
        axes = [axes]  # Ensure axes is iterable for a single pair
    
    for i, (metric_x, metric_y) in enumerate(metric_pairs):
        ax = axes[i]
        if metric_x in history.history and metric_y in history.history:
            ax.plot(history.history[metric_x], history.history[metric_y], marker='o', linestyle='-')
            ax.set_title(f'{metric_x.capitalize()} vs {metric_y.capitalize()}', fontsize=16)
            ax.set_xlabel(metric_x.capitalize(), fontsize=14)
            ax.set_ylabel(metric_y.capitalize(), fontsize=14)
            ax.grid(True)
    
    plt.tight_layout()
    plt.show()

# Example usage
metrics_to_plot = ['accuracy', 'loss', 'dice_coef', 'precision', 'sensitivity', 'specificity']
plot_training_history_enhanced(history, metrics_to_plot)

metric_pairs_to_plot = [('accuracy', 'loss'), ('dice_coef', 'loss'), ('precision', 'sensitivity')]
plot_metric_vs_metric(history, metric_pairs_to_plot)
